# %%
import requests
#pip install pytube
from pytube import YouTube
#import beautifulsoup4

# %%
#while link!='':
    
link = "https://www.youtube.com/watch?v=GWHG3cS2PKc&index=17&list=PLQVvvaa0QuDfKTOs3Keq_kaG2P55YRn5v"
page_content = requests.get(link).text
print(page_content)
page_content.find("ytp-next-button")
#yt = YouTube(link)

#print (f.text)
#a=f.find('Roboto')
# Out:
# <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v16/zN7GBFwfMP4uA6AR0HCoLQ.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v16/RxZJdnzeo3R5zSexge8UUaCWcynf_cDxXwCLxiixG1c.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v16/W4wDsBUluyw0tK3tykhXEfesZW2xOQ-xsNqO47m55DA.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v16/OLffGBTaF0XFOW1gnuHF0Z0EAVxt0G0biEntp43Qt6E.ttf)format('truetype');}</style><script name="www-ro
# ...

# %%
#yt = yt.get('mp4', '720p')
#video.download('/home/suman/Downloads')

# %%
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-13-bb07a52c9499> in <module>()
#       2
#       3 link = "www.google.com"
# ----> 4 f = requests.get(link)
#       5
#       6 print (f.text)
#
# /home/suman/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /home/suman/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# ...

# %%
https://www.youtube.com/watch?v=nSLSkRP6X3U
