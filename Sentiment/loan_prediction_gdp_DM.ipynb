# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# importing data from CSV

df = pd.read_csv('/home/suman/Downloads/fullCleanData2.csv')
diabetes_X = pd.read_csv('/home/suman/Downloads/fullCleanData2.csv')

# %%
# Cleaning Data

diabetes_X.count
diabetes_X.columns
loan_X_train.index
diabetes_X["Original Principal Amount"][0].
# Out:
# '$12350000.00'

# %%
# Sample the data 
#loan_status_y_train = loan_X_train['Loan Status']
loan_X_train_sampling = diabetes_X.sample(78148)
# diabetes_X_train = diabetes_X[["Borrower's Obligation",'Original Principal Amount']][:-20].as_matrix()\
loan_X_train = loan_X_train_sampling[["Interest Rate","currentGDP","Original Principal Amount","Borrower"]]
loan_Y_train = loan_X_train_sampling["Loan Status"]

# %%
# Split the data into training/testing sets
#diabetes_X_train = diabetes_X[:-20]
#diabetes_X_test = diabetes_X[-20:]
# Split the targets into training/testing sets
#diabetes_y_train = diabetes_X.currentGDP[:-20]
#diabetes_y_test = diabetes_X.currentGDP[-20:]

# %%
diabetes_X

from sklearn.ensemble import RandomForestClassifier
X = diabetes_X_train.as_matrix()
Y = diabetes_y_train
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-33c1a4ae5c01> in <module>()
#       5 Y = diabetes_y_train
#       6 clf = RandomForestClassifier(n_estimators=10)
# ----> 7 clf = clf.fit(X, Y)
#
# /home/suman/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     244         """
#     245         # Validate or convert input data
# --> 246         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     247         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     248         if sample_weight is not None:
#
# /home/suman/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
#diabetes_X_train.drop(columns=['B', 'C'])
#diabetes_X_train.as_matrix(columns=None)
#pd.DataFrame(np.random.randn(8, 4), index=dates, columns=['A', 'B', 'C', 'D'])
diabetes_X_train = diabetes_X[["Borrower's Obligation",'Original Principal Amount']][:-20].as_matrix()
diabetes_X_test = diabetes_X[["Borrower's Obligation",'Original Principal Amount']][-20:].as_matrix()

# %%
regr = linear_model.LinearRegression()
regr.fit(diabetes_X_train, diabetes_y_train)
#regr.fit([[2,3,5,6],[2,6,7,9]], [3,7])
# Make predictions using the testing set
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-374ad9f86609> in <module>()
#       1 regr = linear_model.LinearRegression()
# ----> 2 regr.fit(diabetes_X_train, diabetes_y_train)
#       3 #regr.fit([[2,3,5,6],[2,6,7,9]], [3,7])
#       4 # Make predictions using the testing set
#
# /home/suman/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [-1.00013182  1.00113634]
# Mean squared error: 312576563410.29
# Variance score: 0.00

# %%
# Plot outputs
d_x = diabetes_X[['disbursed_amount']][-20:]
#diabetes_X_train = diabetes_X[:-20]
#diabetes_X_test = diabetes_X[-20:]
d_x
#diabetes_y_test
# Out:
#        disbursed_amount
# 23616       38087128.60
# 23617       52315791.09
# 23618        1771879.39
# 23619              0.00
# 23620        3757244.63
# 23621              0.00
# 23622              0.00
# 23623        7290000.00
# 23624         134905.61
# 23625         600000.00
# 23626         753100.74
# 23627         265078.97
# 23628         625000.00
# 23629         206250.00
# 23630         500000.00
# 23631         297500.00
# 23632              0.00
# 23633              0.00
# 23634              0.00
# 23635              0.00

# %%
plt.scatter(d_x, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())
plt.show()

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Load data
dat = sm.datasets.get_rdataset("Guerry", "HistData").data

# Fit regression model (using the natural log of one of the regressors)
results = smf.ols('Lottery ~ Literacy + np.log(Pop1831)', data=dat).fit()

# Inspect the results
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Lottery   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Sat, 07 Apr 2018   Prob (F-statistic):           1.90e-08
# Time:                        18:21:06   Log-Likelihood:                -379.82
# No. Observations:                  86   AIC:                             765.6
# Df Residuals:                      83   BIC:                             773.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         246.4341     35.233      6.995      0.000     176.358     316.510
# ...

# %%
type(dat)
dat
# Out:
#     dept Region           Department  Crime_pers  Crime_prop  Literacy  \
# 0      1      E                  Ain       28870       15890        37
# 1      2      N                Aisne       26226        5521        51
# 2      3      C               Allier       26747        7925        13
# 3      4      E         Basses-Alpes       12935        7289        46
# 4      5      E         Hautes-Alpes       17488        8174        69
# 5      7      S              Ardeche        9474       10263        27
# 6      8      N             Ardennes       35203        8847        67
# 7      9      S               Ariege        6173        9597        18
# 8     10      E                 Aube       19602        4086        59
# 9     11      S                 Aude       15647       10431        34
# 10    12      S              Aveyron        8236        6731        31
# 11    13      S     Bouches-du-Rhone       13409        5291        38
# ...

# %%
X = [[0, 0], [1, 1],[1,2]]
Y = [0, 1,3]
#TYpe()
diabetes_X_train
diabetes_y_train.as_matrix()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(diabetes_X_train, diabetes_y_train.as_matrix())
#clf.predict([[2., 2.]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-44f11f948d12> in <module>()
#       4 #TYpe()
#       5 clf = tree.DecisionTreeClassifier()
# ----> 6 clf = clf.fit(diabetes_X_train, diabetes_y_train.as_matrix())
#       7 #clf.predict([[2., 2.]])
#
# /home/suman/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# /home/suman/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     138
#     139         if is_classification:
# --> 140             check_classification_targets(y)
#     141             y = np.copy(y)
#     142
#
# ...

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris") 
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=iris.feature_names,
                                class_names=iris.target_names,
                                filled=True, rounded=True,  special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/suman/anaconda3/lib/python3.6/site-packages/graphviz/backend.py in render(engine, format, filepath, quiet)
#     123         try:
# --> 124             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     125         except OSError as e:
#
# /home/suman/anaconda3/lib/python3.6/subprocess.py in check_call(*popenargs, **kwargs)
#     285     """
# --> 286     retcode = call(*popenargs, **kwargs)
#     287     if retcode:
#
# /home/suman/anaconda3/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     266     """
# --> 267     with Popen(*popenargs, **kwargs) as p:
#     268         try:
#
# ...
